# %% [markdown]
# # 02 - Preprocessing
#
# Notebook untuk mencoba pipeline preprocessing yang dipakai saat training dan prediksi.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

from src.preprocessing import clean_text

# %%
sample = 'Barang BAGUS banget!!! Pengiriman cepat 2 hari. https://tokopedia.com/test'
clean_text(sample)

# %%
clean_text(sample, use_stemming=False)
