# %% [markdown]
# # 03 - Model Training
#
# Notebook ini menjalankan training MVP yang sama dengan CLI.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path('..').resolve()))

# %%
# Jalankan dari terminal untuk output penuh:
# py -m src.train

# %run ../src/train.py --sample-size 5000

# %%
import pandas as pd

pd.read_csv('../reports/model_comparison.csv')
