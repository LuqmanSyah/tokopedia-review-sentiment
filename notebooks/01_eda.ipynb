# %% [markdown]
# # 01 - EDA
#
# Notebook eksplorasi awal untuk membaca dataset Tokopedia dan melihat struktur dasar data.

# %%
from pathlib import Path
import pandas as pd

DATA_PATH = Path('../data/raw/tokopedia_product_reviews_2025.csv')
df = pd.read_csv(DATA_PATH)
df.head()

# %%
df.info()

# %%
df.isna().sum().sort_values(ascending=False).head(20)

# %%
df.duplicated().sum()

# %%
if 'sentiment_label' in df.columns:
    display(df['sentiment_label'].value_counts())

if 'rating' in df.columns:
    display(df['rating'].value_counts().sort_index())
